# %%
# !tar xvf datasets.tar
# Out:
# datasets/
# datasets/AerialImageDataset/
# datasets/AerialImageDataset/trainB/
# datasets/AerialImageDataset/trainB/vienna1.jpg
# datasets/AerialImageDataset/trainB/vienna17.jpg
# datasets/AerialImageDataset/trainB/vienna30.jpg
# datasets/AerialImageDataset/trainB/kitsap8.jpg
# datasets/AerialImageDataset/trainB/tyrol-w20.jpg
# datasets/AerialImageDataset/trainB/vienna36.jpg
# datasets/AerialImageDataset/trainB/kitsap4.jpg
# datasets/AerialImageDataset/trainB/kitsap30.jpg
# datasets/AerialImageDataset/trainB/vienna25.jpg
# datasets/AerialImageDataset/trainB/vienna33.jpg
# datasets/AerialImageDataset/trainB/tyrol-w35.jpg
# datasets/AerialImageDataset/trainB/austin8.jpg
# datasets/AerialImageDataset/trainB/kitsap28.jpg
# datasets/AerialImageDataset/trainB/austin13.jpg
# datasets/AerialImageDataset/trainB/kitsap14.jpg
# datasets/AerialImageDataset/trainB/tyrol-w34.jpg
# datasets/AerialImageDataset/trainB/chicago6.jpg
# datasets/AerialImageDataset/trainB/tyrol-w26.jpg
# ...

# %%
'''!CUDA_VISIBLE_DEVICES=0 python main.py --dataset_dir=AerialImageDataset'''
# Out:
# 2018-01-14 12:53:03.218267: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:0b:00.0
# totalMemory: 15.77GiB freeMemory: 15.36GiB
# 2018-01-14 12:53:03.218348: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1120] Creating TensorFlow device (/device:GPU:0) -> (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:0b:00.0, compute capability: 7.0)
# generatorA2B/g_e1_c/Conv/weights:0
# generatorA2B/g_e1_bn/scale:0
# generatorA2B/g_e1_bn/offset:0
# generatorA2B/g_e2_c/Conv/weights:0
# generatorA2B/g_e2_bn/scale:0
# generatorA2B/g_e2_bn/offset:0
# generatorA2B/g_e3_c/Conv/weights:0
# generatorA2B/g_e3_bn/scale:0
# generatorA2B/g_e3_bn/offset:0
# generatorA2B/g_r1_c1/Conv/weights:0
# generatorA2B/g_r1_bn1/scale:0
# generatorA2B/g_r1_bn1/offset:0
# generatorA2B/g_r1_c2/Conv/weights:0
# generatorA2B/g_r1_bn2/scale:0
# generatorA2B/g_r1_bn2/offset:0
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --dataset_dir=AerialImageDataset --phase=test --which_direction=BtoA
# Out:
# 2018-01-15 03:15:21.981929: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:0b:00.0
# totalMemory: 15.77GiB freeMemory: 15.36GiB
# 2018-01-15 03:15:21.981982: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1120] Creating TensorFlow device (/device:GPU:0) -> (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:0b:00.0, compute capability: 7.0)
# generatorA2B/g_e1_c/Conv/weights:0
# generatorA2B/g_e1_bn/scale:0
# generatorA2B/g_e1_bn/offset:0
# generatorA2B/g_e2_c/Conv/weights:0
# generatorA2B/g_e2_bn/scale:0
# generatorA2B/g_e2_bn/offset:0
# generatorA2B/g_e3_c/Conv/weights:0
# generatorA2B/g_e3_bn/scale:0
# generatorA2B/g_e3_bn/offset:0
# generatorA2B/g_r1_c1/Conv/weights:0
# generatorA2B/g_r1_bn1/scale:0
# generatorA2B/g_r1_bn1/offset:0
# generatorA2B/g_r1_c2/Conv/weights:0
# generatorA2B/g_r1_bn2/scale:0
# generatorA2B/g_r1_bn2/offset:0
# ...
